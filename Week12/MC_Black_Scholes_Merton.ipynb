# %% [markdown]
# ## Monte Carlo - Black-Scholes-Merton

# %% [markdown]
# Tải dữ liệu cho Microsoft (‘MSFT’) trong giai đoạn ‘2000-1-1’ cho đến nay.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
from scipy.stats import norm

data = pd.read_csv('D:/Python/MSFT_2000.csv', index_col = 'Date')

# %%
def d1(S, K, r, stdev, T):
    return (np.log(S / K) + (r + stdev ** 2 / 2) * T) / (stdev * np.sqrt(T))

def d2(S0, K, r, stdev, T):
    return (np.log(S / K) + (r - stdev ** 2 / 2) * T) / (stdev * np.sqrt(T))

def BSM(S, K, r, stdev, T):
        return (S * norm.cdf(d1(S, K, r, stdev, T))) - (K * np.exp(-r * T) * norm.cdf(d2(S, K, r, stdev, T)))

# %% [markdown]
# Lưu trữ độ lệch chuẩn hàng năm của logarit lợi nhuận trong một biến có tên là “stdev”.

# %%
log_returns = np.log(1 + data.pct_change())

# %%
log_returns.tail()
# Out:
#                 MSFT
# Date
# 2017-10-12  0.009118
# 2017-10-13  0.004786
# 2017-10-16  0.002063
# 2017-10-17 -0.000773
# 2017-10-18  0.000258

# %%
stdev = log_returns.std() * 250 ** 0.5
stdev
# Out:
# MSFT    0.306691
# dtype: float64

# %% [markdown]
# Đặt lãi suất không rủi ro r bằng 2,5% (0,025); giá thực hiện K bằng 110,0; và khung thời gian T bằng 1 tương ứng.

# %%
r = 0.025
K = 110.0
T = 1

# %% [markdown]
# Tạo một biến S bằng giá đóng cửa điều chỉnh gần nhất của Microsoft. Sử dụng phương pháp "iloc"

# %%
S = data.iloc[-1]
S
# Out:
# MSFT    77.610001
# Name: 2017-10-18, dtype: float64

# %% [markdown]
# Gọi các hàm d1 và d2 với các đối số có liên quan để lấy giá trị của chúng.

# %%
d1(S, K, r, stdev, T)
# Out:
# MSFT   -0.902389
# dtype: float64

# %%
d2(S, K, r, stdev, T)
# Out:
# MSFT   -1.20908
# dtype: float64

# %% [markdown]
# Sử dụng hàm BSM để ước tính giá của quyền chọn mua, với điều kiện bạn biết các giá trị S, K, r, stdev và T.

# %%
BSM(S, K, r, stdev, T)
# Out:
# MSFT    2.078609
# Name: 2017-10-18, dtype: float64
